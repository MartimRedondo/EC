# %% [markdown]
# ## Teste - Polynomials

# %%
# !sage -python test_polynomials_sage.py
# Out:
# ...................
# ----------------------------------------------------------------------
# Ran 19 tests in 0.191s
#
# OK

# %% [markdown]
# ## Teste - Modules

# %%
# !sage -python test_modules_sage.py
# Out:
# Teste: Matrizes de polinómios
# -> OK
# Todos os testes passaram com sucesso.
# ............
# ----------------------------------------------------------------------
# Ran 12 tests in 0.047s
#
# OK

# %% [markdown]
# ## Teste - Dilithium

# %%
# !sage -python test_dilithium_sage.py
# Out:
# Teste: Matrizes de polinómios
# -> OK
# Todos os testes passaram com sucesso.
# RHO - SIGN:
# 2705cf2731684931527a7e79e94f548351b9f5dbc7cbbaf0663767f51a05415f
# Tentativa de assinatura 1
# w1 assinatura exemplo: [[56, 396, 82, 305], [271, 32, 213, 89]]
# Challenge generation started
# 10/39 non-zero coefficients set
# 20/39 non-zero coefficients set
# 30/39 non-zero coefficients set
# Challenge generated
# Assinatura aceite
# Início da verificação
# c_bytes extraído: 77c4e1e5db74a666fc17e0bc107ead3c86fbf06360f00605e875814856cb0921
# z_bytes extraído com comprimento: 2304
# z descompactado
# RHO - VERIFY
# 2705cf2731684931527a7e79e94f548351b9f5dbc7cbbaf0663767f51a05415f
# Chave pública descompactada
# Digest mu computado
# Matriz A expandida
# Matriz A igual à usada na assinatura? True
# Comparação com valores da assinatura:
# mu assinada == mu verificada? False
# Challenge generation started
# 10/39 non-zero coefficients set
# 20/39 non-zero coefficients set
# ...
